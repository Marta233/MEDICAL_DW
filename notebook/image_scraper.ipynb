# %% [markdown]
# ## -- Task_1 scraping telegram Image data

# %%
import sys
sys.path.insert(0, '/10 A KAI 2/week 7/DW/')
import pandas as pd

# %%
from scrpts.Image_scraping import TelegramImageScraper

# %%
scraper = TelegramImageScraper()

# %% [markdown]
# #### -  List of channels to be scrape

# %%
channels = ["ChemedTelegramChannel",
        "lobelia4cosmetics",]

# %%
await scraper.connect()

# %% [markdown]
# ### - Fetch all data from the listed telegram channels and the extracted the images and stored in .downloads dire.

# %%
await scraper.fetch_images_from_channels(channels)
# Out:
# Joining and fetching images from ChemedTelegramChannel...
# Error fetching images from ChemedTelegramChannel: No user has "chemedtelegramchannel" as username
# Joining and fetching images from lobelia4cosmetics...
# Downloaded image to downloads\photo_2024-10-10_04-07-51.jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-51 (1).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-51 (2).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-51 (3).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50.jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50 (1).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50 (2).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50 (3).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50 (4).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50 (5).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50 (6).jpg
# Downloaded image to downloads\photo_2024-10-10_04-07-50 (7).jpg
# ...
