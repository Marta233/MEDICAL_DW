# %% [markdown]
# ## -- Task_1 scraping telegram data

# %%
import sys
sys.path.insert(0, '/10 A KAI 2/week 7/DW/')
import pandas as pd

# %%
from scrpts.Data_scraping import TelegramChannelScraper

# %%
scraper = TelegramChannelScraper()

# %% [markdown]
# #### -  List of channels to be scrape

# %%
channels = ["DoctorsET",
        "ChemedTelegramChannel",
        "lobelia4cosmetics",
        "yetenaweg",
        "EAHCI"]

# %% [markdown]
# ### - Fetch all data from the listed telegram channels and the extracted data stored in .json file format in the project folder.

# %%
# Run the fetching process
await scraper.connect()
await scraper.fetch_messages_from_channels(channels)
# Out:
# Joining and fetching messages from DoctorsET...
# Saving message 864 from DoctorsET
# Saving message 863 from DoctorsET
# Saving message 862 from DoctorsET
# Saving message 861 from DoctorsET
# Saving message 860 from DoctorsET
# Saving message 859 from DoctorsET
# Saving message 848 from DoctorsET
# Saving message 847 from DoctorsET
# Saving message 846 from DoctorsET
# Saving message 845 from DoctorsET
# Saving message 844 from DoctorsET
# Saving message 843 from DoctorsET
# Saving message 842 from DoctorsET
# Saving message 841 from DoctorsET
# Saving message 840 from DoctorsET
# Saving message 839 from DoctorsET
# Saving message 836 from DoctorsET
# Saving message 835 from DoctorsET
# Saving message 834 from DoctorsET
# Saving message 833 from DoctorsET
# Saving message 832 from DoctorsET
# Saving message 831 from DoctorsET
# Saving message 830 from DoctorsET
# Saving message 829 from DoctorsET
# Saving message 828 from DoctorsET
# Saving message 827 from DoctorsET
# ...
