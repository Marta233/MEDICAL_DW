# %%
import sys
sys.path.insert(0, '/10 A KAI 2/week 7/DW/')
import pandas as pd

# %%
from scrpts.Obj_detection import YOLOv5Detector

# %%
image_folder = 'D:/10 A KAI 2/week 7/DW/notebook/downloads'

# %%
# Instantiate the detector
detector = YOLOv5Detector(base_output_folder='./YOLO_output')
# Out:
# Loading YOLOv5 model: yolov5s
# Using cache found in C:\Users\marta/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-10-13 Python-3.11.2 torch-2.4.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# Table 'detections' created or exists already.

# %%
# Run the detection pipeline
detections_df= detector.detect_objects_in_images(image_folder)
# Out:
# C:\Users\marta/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs\detect\exp3131
# C:\Users\marta/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processed 10.jpg and moved detected image to ./YOLO_output\10.jpg
# Saved 1 image to runs\detect\exp3132
# Processed 10113.jpg and moved detected image to ./YOLO_output\10113.jpg
# C:\Users\marta/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs\detect\exp3133
# ...

# %%
    # Save detections to CSV
detector.save_to_csv(detections_df)
# Out:
# Saved all detections to ./YOLO_output\all_images_detections.csv
# './YOLO_output\\all_images_detections.csv'

# %%
    # Insert data into PostgreSQL
detector.insert_detections_to_db(detections_df)
# Out:
# Data inserted into PostgreSQL.

# %%
     # Close database connection
detector.conn.close()
print("Pipeline complete, database connection closed.")
# Out:
# Pipeline complete, database connection closed.
